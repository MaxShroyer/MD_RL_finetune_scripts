# %% [markdown]
# # PI&D Icons Pipeline
#
# Run order:
# 1. Build merged dataset with leakage-safe splits
# 2. Train class-conditional detector
# 3. Benchmark baseline vs finetuned checkpoint

# %%
# %cd ..
# !pwd

# %%
# !python build_pid_hf_dataset.py \
  --dataset1-dir datasets/raw/Dataset1 \
  --pid2graph-dir datasets/raw/PID2Graph \
  --label-key datasets/raw/Dataset1/lable_key.txt \
  --output-dir outputs/pid_datasets_merged \
  --seed 42 \
  --val-fraction 0.20 \
  --post-val-fraction 0.10

# %%
# !python train_pid_icons.py \
  --env-file .env \
  --dataset-path "outputs/pandid_dataset" \
  --split train \
  --val-split val \
  --num-steps 200 \
  --batch-size 16 \
  --group-size 8 \
  --neg-prompts-per-empty 0 \
  --neg-prompts-per-nonempty 0 \
  --eval-every 10 \
  --save-every 10 \
  --off-policy 



  # python build_pid_hf_dataset.py \
  # --dataset1-dir datasets/raw/Dataset1 \
  # --label-key datasets/raw/Dataset1/lable_key.txt \
  # --output-dir outputs/pandid_dataset_v2 \
  # --seed 42 \
  # --val-fraction 0.20 \
  # --post-val-fraction 0.10 --push-to-hub maxs-m87/pandid_dataset_v2  --hub-val-split val \
  # --hub-post-val-split post_val  --post-val-fraction 0.1

# %%
# Replace <FINETUNE_ID> and <CHECKPOINT_STEP> after training
# !python benchmark_pid_icons.py \
  --env-file .env \
  --dataset-path outputs/pandid_dataset_v2 \
  --split post_val \
  --finetune-id "01KH6SRJTREQ0V8BGYS4WXC8WK" \
  --checkpoint-step 20 \
  --out-json outputs/bench2/benchmark_pid_icons.json \
  --viz-dir outputs/bench2/viz_pid_icons/ \
  --max-post-train-eval-samples 50 \
  --viz-samples 50
